# %% [markdown]
# <center>
#     <strong>
#     Name - SOUMYA BASU <br>
#     Reg No. - 23MDT0047 <br>
#     Multivariate Data Analysis Lab DA1 <br>
#     MAT5017
# </center>

# %% [markdown]
# ### Problem 1:
# #### Generate data of size 250, 300 and 500 from bivariate and trivariate normal and standard normal distributions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# Set the random seed for reproducibility
np.random.seed(42)

# Parameters for bivariate normal distribution
mean_bivariate = [0, 0]
cov_bivariate = [[1, 0.5], [0.5, 1]]  # Covariance matrix

# Parameters for trivariate normal distribution
mean_trivariate = [0, 0, 0]
cov_trivariate = [[1, 0.5, 0.3], [0.5, 1, 0.4], [0.3, 0.4, 1]]  # Covariance matrix

# Generate data
data_bivariate_250 = np.random.multivariate_normal(mean_bivariate, cov_bivariate, 250)
data_bivariate_300 = np.random.multivariate_normal(mean_bivariate, cov_bivariate, 300)
data_bivariate_500 = np.random.multivariate_normal(mean_bivariate, cov_bivariate, 500)

data_trivariate_250 = np.random.multivariate_normal(mean_trivariate, cov_trivariate, 250)
data_trivariate_300 = np.random.multivariate_normal(mean_trivariate, cov_trivariate, 300)
data_trivariate_500 = np.random.multivariate_normal(mean_trivariate, cov_trivariate, 500)

# Generate data from standard normal distribution
data_standard_normal_250 = np.random.randn(250)
data_standard_normal_300 = np.random.randn(300)
data_standard_normal_500 = np.random.randn(500)

# %%
# Output the shapes to verify the sizes
print("Bivariate (250 samples): \n", data_bivariate_250[:20])
print("----------------------------------------")
print("Bivariate (300 samples): \n", data_bivariate_300[:20])
print("----------------------------------------")
print("Bivariate (500 samples): \n", data_bivariate_500[:20])
# Out:
# Bivariate (250 samples):
#  [[-0.36103492 -0.49929923]
#  [-1.32242966  0.2006002 ]
#  [ 0.31985125  0.08571429]
#  [-1.75135578 -0.98392105]
#  [ 0.13529672  0.67785677]
#  [ 0.63419637  0.16846662]
#  [ 0.74709465 -1.1661856 ]
#  [ 1.77496643  1.2126789 ]
#  [ 0.72001381  1.03426115]
#  [ 1.49252377  0.08022007]
#  [-1.15640092 -1.38217722]
#  [ 0.65389295 -0.77085523]
#  [ 0.41598797  0.52691056]
#  [ 0.80894067  1.18463869]
#  [ 0.66601524  0.37432149]
#  [-0.40504588  1.4472323 ]
#  [ 0.5405444  -0.51716652]
#  [-0.10192296 -1.32276661]
#  [ 0.79895388 -1.16071624]
#  [ 1.05181224  1.24867348]]
# ----------------------------------------
# Bivariate (300 samples):
#  [[-1.7568016   0.15261504]
#  [ 0.92971043  1.49267967]
#  [ 0.80703569  0.3199103 ]
#  [ 0.94502357  0.0810328 ]
#  [ 0.3734541  -0.45749602]
#  [-0.20910343 -0.25934154]
#  [ 0.66071691 -0.24684675]
#  [ 0.12180301  0.87719424]
#  [ 0.05497061 -0.92258463]
#  [-0.46171786  0.28966926]
#  [ 1.17406729  1.71742748]
#  [ 0.28854967  0.85914834]
#  [ 1.56344287 -0.24143923]
#  [ 1.38545062  1.43353557]
#  [ 0.22723203 -0.6770846 ]
#  [ 0.27772274 -1.38379732]
#  [ 0.66273488 -0.54828132]
#  [ 0.54080729  0.58820596]
#  [ 0.9374176   0.55286206]
#  [-0.5830292  -1.15992107]]
# ----------------------------------------
# Bivariate (500 samples):
#  [[ 0.58382558 -2.3124298 ]
#  [-1.73879073 -1.87838036]
#  [-0.43976151 -1.47966743]
#  [-0.00396999 -1.05738555]
#  [-0.41681591  1.49721544]
#  [ 0.05641937  0.27385224]
#  [-1.0013417  -0.50565981]
#  [-0.31274709  0.05221391]
#  [-2.05260955 -2.11022835]
#  [-0.69948408  0.35117031]
#  [-1.5509287  -0.36389839]
#  [ 0.01834586 -1.12465905]
#  [-0.84142051 -1.9877659 ]
#  [ 0.11504792 -0.63922793]
#  [-0.10883577  0.21992664]
#  [-0.48926389 -0.06734314]
#  [-1.6242821  -1.1707478 ]
#  [-0.27059774  0.69348943]
#  [-0.41630775 -1.64391557]
#  [-0.86795001 -0.16677727]]

# %%
print("Trivariate (250 samples): \n", data_trivariate_250[:20])
print("----------------------------------------")
print("Trivariate (300 samples): \n", data_trivariate_300[:20])
print("----------------------------------------")
print("Trivariate (500 samples): \n", data_trivariate_500[:20])
# Out:
# Trivariate (250 samples):
#  [[-1.07563319  0.01756107  0.20679711]
#  [-0.75560606 -1.98297631  0.30374543]
#  [ 0.86604256  1.01842921  0.14040111]
#  [-0.79294566 -0.49560097 -0.07905899]
#  [-0.19404713 -0.57154796  0.78662875]
#  [-0.1174108   0.92359219  0.35004784]
#  [ 2.91044556  0.8318472   2.350192  ]
#  [-0.73066318 -0.51850712 -0.58513129]
#  [-0.25029171  0.68673216 -0.59325519]
#  [-0.23879368 -1.20903079 -1.15604553]
#  [-0.05494091 -0.72056674 -0.20830658]
#  [-0.86516039 -0.24069692 -0.27172799]
#  [ 0.13204109  0.79544622 -1.34835657]
#  [ 1.24443623  1.22233453  0.93081644]
#  [-0.11368728  0.00879249 -0.32811923]
#  [-2.25513231 -1.03472721 -0.09113789]
#  [-0.76042315 -0.05670645  1.1731791 ]
#  [-1.19262182 -1.50709551 -1.14741234]
#  [ 0.54092965  1.1630046   1.24924506]
#  [ 1.07819465  0.1536104  -0.56243645]]
# ----------------------------------------
# Trivariate (300 samples):
#  [[ 3.60784314e-01  1.16424215e+00 -3.74486363e-01]
#  [ 1.84881495e-01  2.63375097e-01 -1.08077296e+00]
#  [ 9.41120607e-01 -5.97962828e-02  8.66010376e-01]
#  [-1.99804564e-01 -4.95364664e-01  3.10827799e-01]
#  [ 1.34869557e+00  8.01694450e-01  3.78678708e-01]
#  [-5.18529071e-01  6.07169671e-01  6.43026877e-01]
#  [-1.06809996e-01  6.83644110e-02 -1.33123982e+00]
#  [-1.57579957e+00 -3.72618925e-01  1.01257658e+00]
#  [-7.88568303e-01  3.92257903e-01  4.88173374e-01]
#  [ 5.80744562e-01  6.99178190e-01  2.38300642e-01]
#  [ 5.05686907e-01  1.88652274e+00  2.93467705e+00]
#  [-1.84895538e+00 -5.12073401e-01  1.48183469e+00]
#  [ 9.00926338e-01  8.43543083e-01 -6.49209839e-01]
#  [-1.11464552e+00  8.31429211e-01 -7.30190297e-01]
#  [-2.89065481e-01 -8.80428199e-01 -6.03658046e-01]
#  [-3.32783068e+00 -4.49436481e+00 -1.04310706e+00]
#  [ 3.40054745e-01  3.05549711e-01 -2.56667758e-03]
#  [ 2.01281383e-01  9.74575041e-02  7.47407928e-01]
#  [ 1.36387836e+00  1.59598606e+00  4.83358988e-01]
#  [ 1.19247423e+00  2.11763219e-01  1.32098129e+00]]
# ----------------------------------------
# Trivariate (500 samples):
#  [[ 1.12994098 -0.12837084  0.40038571]
#  [-0.78820105  1.3199802   0.45716429]
#  [ 0.98878844  0.06003185 -1.43039899]
#  [ 0.16341237  0.07081106 -0.207713  ]
#  [ 1.1134352   0.67756369  0.04581035]
#  [ 0.06951067 -0.84691931  0.88043739]
#  [-0.36325262 -1.16646584  0.0819036 ]
#  [-0.2913041   0.70638846  0.75962423]
#  [ 0.84629558  2.51901679  0.61350571]
#  [-0.04652479  0.77319358  2.27982377]
#  [-0.4667034   0.63200436  0.15325465]
#  [ 0.905016    1.33806202  0.41396101]
#  [-0.58612815 -0.48763257  0.41652769]
#  [-0.9146013  -0.78526197 -1.39300904]
#  [-0.31017779 -0.25359979 -0.01459561]
#  [ 0.26526231  0.13572679  0.37890329]
#  [-0.273563    1.42064228  1.16324387]
#  [ 0.74683878  1.07682625  1.99360795]
#  [ 0.95190994  0.80107377  0.28256998]
#  [ 2.17939944  1.3078496   1.0765086 ]]

# %%
print("Standard Normal (250 samples): \n", data_standard_normal_250[:20])
print("----------------------------------------")
print("Standard Normal (300 samples): \n", data_standard_normal_300[:20])
print("----------------------------------------")
print("Standard Normal (500 samples): \n", data_standard_normal_500[:20])
# Out:
# Standard Normal (250 samples):
#  [-0.96578263 -0.53857367 -0.46675881 -1.48298443 -0.8176824  -1.13383036
#  -0.41247901 -0.7386975  -1.62700492  2.02259023  1.25254073 -0.77901942
#   0.2724214   0.41746509  1.19108585 -0.81860503  1.09210678 -0.5479053
#  -1.3358624   0.72413656]
# ----------------------------------------
# Standard Normal (300 samples):
#  [ 0.70314254  0.53320732  0.16540366 -1.38201757 -0.48361714  0.84178077
#  -1.05122003 -2.53176932 -0.22710601 -0.14175755  0.13556342  0.72851864
#   0.63760581  0.25876981  1.19553139 -1.51896978  0.50458181  0.62653836
#  -1.23956229 -1.50287061]
# ----------------------------------------
# Standard Normal (500 samples):
#  [ 0.29523258 -0.23823368 -0.41051848  1.81889853  1.17718496  0.13674665
#  -2.30421194 -0.36100922  2.70302756 -0.23066167  1.10321757  1.4419424
#   0.21896392 -0.84182163 -2.43531233  0.68416321 -0.814756    0.17615045
#  -1.24982034 -0.26523754]

# %% [markdown]
# ### Problem 2:
# #### Obtain the Maximum Likelihood Estimate of mean vector and variance covariance matrix for Weight, Hieght and MRI from the following data. Assume that the data comes from normal distribution. Also draw Q-Q Plot for these considered variables.

# %%
# Data
data = pd.read_excel("female.xlsx")

data
# Out:
#     Gender  FSIQ  VIQ  PIQ  Weight  Height     MRI
# 0   Female   133  132  124     118    64.5  816932
# 1   Female   137  132  134     147    65.0  951545
# 2   Female    99   90  110     146    69.0  928799
# 3   Female   138  136  131     138    64.5  991305
# 4   Female    92   90   98     175    66.0  854258
# 5   Female   132  129  124     118    64.5  833868
# 6   Female   140  120  147     155    70.5  856472
# 7   Female    96  100   90     146    66.0  878897
# 8   Female    83   71   96     135    68.0  865363
# 9   Female   132  132  120     127    68.5  852244
# 10  Female   101  112   84     136    66.3  808020
# 11  Female   135  129  134     122    62.0  790619
# 12  Female    91   86  102     114    63.0  831772
# 13  Female    85   90   84     140    68.0  798612
# 14  Female    77   83   72     106    63.0  793549
# 15  Female   130  126  124     159    66.5  866662
# 16  Female   133  126  132     127    62.5  857782
# 17  Female    83   90   81     143    66.5  834344
# 18  Female   133  129  128     153    66.5  948066
# 19  Female    88   86   94     139    64.5  893983

# %%
# Calculate the Mean Vector
mean_vector = df.mean()
print("Mean Vector:")
print(mean_vector)
# Out:
# Mean Vector:
# Weight    112.70
# Height    109.00
# MRI       110.65
# dtype: float64

# %%
# Calculate the Variance-Covariance Matrix
cov_matrix = df.cov()
print("\nVariance-Covariance Matrix:")
print(cov_matrix)
# Out:
# Variance-Covariance Matrix:
#             Weight      Height         MRI
# Weight  525.168421  480.684211  448.626316
# Height  480.684211  492.105263  384.631579
# MRI     448.626316  384.631579  458.660526

# %%
# Q-Q plots
for col in df.columns:
    plt.figure()
    stats.probplot(df[col], dist="norm", plot=plt)
    plt.title(f"Q-Q Plot of {col}")
    plt.show()

# %% [markdown]
# ### Problem 3:
# #### Draw the scatter plot matrix for Male between all the variables from the following data. Consider line, histogram and density plots diagonally in separate plots.

# %%
df = pd.read_excel("male.xlsx")

# %%
import seaborn as sns

# %%
# Create a pairplot with different kinds of plots on the diagonal
g = sns.pairplot(df, diag_kind='kde', kind='scatter', diag_kws={'fill': True, 'linewidth': 2})

# Customize the plots
for i, j in zip(*np.tril_indices_from(g.axes, -1)):
    g.axes[i, j].set_xlabel('')
    g.axes[i, j].set_ylabel('')

plt.show()
